# %%
import xarray as xr
import pandas as pd

# %% [markdown]
# # BCO

# %%
PLATFORM = 'BCO'
BCO = xr.open_zarr(f"ipns://latest.orcestra-campaign.org/products/{PLATFORM}/RS_{PLATFORM}_level2.zarr").compute()

# %%
BCO_ascent = BCO.where(BCO.ascent_flag == 0, drop=True)
BCO_ascent
# Out:
# <xarray.Dataset> Size: 38MB
# Dimensions:      (sounding: 140, alt: 3100, nv: 2)
# Coordinates:
#   * alt          (alt) int16 6kB 0 10 20 30 40 ... 30950 30960 30970 30980 30990
#     flight_time  (sounding, alt) datetime64[ns] 3MB NaT NaT NaT ... NaT NaT NaT
#     lat          (sounding, alt) float32 2MB nan nan nan 13.16 ... nan nan nan
#     launch_time  (sounding) datetime64[ns] 1kB 2024-09-07T01:05:09.939968 ......
#     lon          (sounding, alt) float32 2MB nan nan nan -59.43 ... nan nan nan
#   * nv           (nv) int64 16B 0 1
#     p            (sounding, alt) float32 2MB nan nan nan ... nan nan nan
#   * sounding     (sounding) <U43 24kB 'BCO__ascent__13.16_-59.43__20240907010...
# Data variables: (12/18)
#     N_gps        (sounding, alt) float32 2MB nan nan nan 1.0 ... nan nan nan nan
#     N_ptu        (sounding, alt) float32 2MB nan nan nan 1.0 ... nan nan nan nan
#     alt_bnds     (alt, nv, sounding) float32 3MB -5.0 -5.0 -5.0 ... 19.0 19.0
# ...

# %% [markdown]
# # Sal

# %%
PLATFORM = 'SAL'
SAL = xr.open_zarr(f"ipns://latest.orcestra-campaign.org/products/{PLATFORM}/RS_{PLATFORM}_level2.zarr").compute()

# %%
SAL_ascent = SAL.where(SAL.ascent_flag == 0, drop=True)
SAL_ascent
# Out:
# <xarray.Dataset> Size: 42MB
# Dimensions:      (sounding: 152, alt: 3100, nv: 2)
# Coordinates:
#   * alt          (alt) int16 6kB 0 10 20 30 40 ... 30950 30960 30970 30980 30990
#     flight_time  (sounding, alt) datetime64[ns] 4MB NaT NaT NaT ... NaT NaT NaT
#     lat          (sounding, alt) float32 2MB nan nan nan nan ... nan nan nan nan
#     launch_time  (sounding) datetime64[ns] 1kB 2024-08-09T17:47:55 ... 2024-0...
#     lon          (sounding, alt) float32 2MB nan nan nan nan ... nan nan nan nan
#   * nv           (nv) int64 16B 0 1
#     p            (sounding, alt) float32 2MB nan nan nan nan ... nan nan nan nan
#   * sounding     (sounding) <U43 26kB 'SAL__ascent__16.73_-22.94__20240809174...
# Data variables: (12/18)
#     N_gps        (sounding, alt) float32 2MB nan nan nan nan ... nan nan nan nan
#     N_ptu        (sounding, alt) float32 2MB nan nan nan nan ... nan nan nan nan
#     alt_bnds     (alt, nv, sounding) float32 4MB -5.0 -5.0 -5.0 ... 19.0 19.0
# ...

# %% [markdown]
# # Meteor

# %%
PLATFORM = 'METEOR'
MET = xr.open_zarr(f"ipns://latest.orcestra-campaign.org/products/{PLATFORM}/RS_{PLATFORM}_level2.zarr").compute()

# %%
MET_ascent = MET.where(MET.ascent_flag == 0, drop=True)
MET_ascent
# Out:
# <xarray.Dataset> Size: 88MB
# Dimensions:      (sounding: 321, alt: 3100, nv: 2)
# Coordinates:
#   * alt          (alt) int16 6kB 0 10 20 30 40 ... 30950 30960 30970 30980 30990
#     flight_time  (sounding, alt) datetime64[ns] 8MB NaT ... NaT
#     lat          (sounding, alt) float32 4MB nan 16.89 16.89 ... nan nan nan
#     launch_time  (sounding) datetime64[ns] 3kB 2024-08-14T19:50:59.362998016 ...
#     lon          (sounding, alt) float32 4MB nan -25.0 -25.0 ... nan nan nan
#   * nv           (nv) int64 16B 0 1
#     p            (sounding, alt) float32 4MB nan 1.01e+05 1.008e+05 ... nan nan
#   * sounding     (sounding) <U43 55kB 'METEOR__ascent__16.89_-25.00__20240814...
# Data variables: (12/18)
#     N_gps        (sounding, alt) float32 4MB nan 1.0 2.0 2.0 ... nan nan nan nan
#     N_ptu        (sounding, alt) float32 4MB nan 1.0 2.0 2.0 ... nan nan nan nan
#     alt_bnds     (alt, nv, sounding) float32 8MB -5.0 -5.0 -5.0 ... 19.0 19.0
# ...
